# %%
import pandas as pd
import numpy as np
import re
import time

from pathlib import Path
from collections import Counter

# %%
file_path = "Data/movies_metadata.csv"
metadata_df = pd.read_csv(file_path, low_memory=False)
metadata_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
metadata_df = metadata_df.drop(columns=["adult", "belongs_to_collection", "budget", "genres", "homepage", "original_language", "original_title", "overview", "revenue", "spoken_languages", "status", "tagline", "video", "vote_average", "vote_count"])
metadata_df.head()
# Out:
#       id    imdb_id popularity                       poster_path  \
# 0    862  tt0114709  21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1   8844  tt0113497  17.015539  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2  15602  tt0113228    11.7129  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3  31357  tt0114885   3.859495  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4  11862  tt0113041   8.387519  /e64sOI48hQXyru7naBFyssKFxVd.jpg
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30     81.0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15    104.0
# ...

# %%
metadata_df = metadata_df.drop(columns=["imdb_id", "popularity", "poster_path", "production_companies", "production_countries"])
metadata_df.head()
# Out:
#       id release_date  runtime                        title
# 0    862   1995-10-30     81.0                    Toy Story
# 1   8844   1995-12-15    104.0                      Jumanji
# 2  15602   1995-12-22    101.0             Grumpier Old Men
# 3  31357   1995-12-22    127.0            Waiting to Exhale
# 4  11862   1995-02-10    106.0  Father of the Bride Part II

# %%
metadata_df.isnull().count()
# Out:
# id              45466
# release_date    45466
# runtime         45466
# title           45466
# dtype: int64

# %%
metadata_df = metadata_df.dropna()
metadata_df.count()
# Out:
# id              45130
# release_date    45130
# runtime         45130
# title           45130
# dtype: int64

# %%
metadata_df.to_csv("Data/movies_metadata_clean.csv")
